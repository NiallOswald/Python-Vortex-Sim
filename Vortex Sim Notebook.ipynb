# %%
from vortexSim import VortexSim
import matplotlib as plt
# %matplotlib inline

# %%
vortex_points = [(-1, -1), (-1, 1), (1, -1), (1, 1)]
strengths = [-1, 1, -1, 1]
dimensions = ((-2, -2), (10, 2))

# %%
sim = VortexSim(vortex_points, dimensions = dimensions, strengths = strengths, damping = 0.001)
sim.save_sim(frames = 200)
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.

# %%
from vortexSim import VortexStreet

# %%
dxdtf = lambda x, y: 1
dydtf = lambda x, y: 0

underlying_velocity = (dxdtf, dydtf)

# %%
generation_points = ((0, 1), (0, -1))

# %%
period = 50

# %%
sim = VortexStreet(generation_points, period, underlying_velocity, damping = 0.01, dimensions = ((-2, -2), (10, 2)))

# %%
sim.save_sim(frames = 400, interval = 50, delta = 0.025)
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
