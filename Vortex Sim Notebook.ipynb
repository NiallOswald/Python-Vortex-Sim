# %%
from vortexSim import VortexSim
import matplotlib as plt
# %matplotlib inline

# %%
sim = VortexSim([(-1, 0), (1, 0)], -2, -2, 2, 2)
sim.save_sim()
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
